# %%
name = "Miri"
reason = "I’m very interested in this new world I’ve discovered and I want to understand how it works"
fun_fact = "My goal is to keep learning and become confident working with technology"

print(f"Hi! My name is {name}. I’m excited to learn because {reason}. A fun fact about me is: {fun_fact}.")
